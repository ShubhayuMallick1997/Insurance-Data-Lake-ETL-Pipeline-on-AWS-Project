# %%
import os
import urllib.request
import ssl

data_dir = "data"
os.makedirs(data_dir, exist_ok=True)

data_dir1 = "hadoop/bin"
os.makedirs(data_dir1, exist_ok=True)

urls_and_paths = {
    "https://raw.githubusercontent.com/saiadityaus1/SparkCore1/master/test.txt": os.path.join(data_dir, "test.txt"),
    "https://github.com/saiadityaus1/SparkCore1/raw/master/winutils.exe": os.path.join(data_dir1, "winutils.exe"),
    "https://github.com/saiadityaus1/SparkCore1/raw/master/hadoop.dll": os.path.join(data_dir1, "hadoop.dll")
}

# Create an unverified SSL context
ssl_context = ssl._create_unverified_context()

for url, path in urls_and_paths.items():
    # Use the unverified context with urlopen
    with urllib.request.urlopen(url, context=ssl_context) as response, open(path, 'wb') as out_file:
        data = response.read()
        out_file.write(data)
import os, urllib.request, ssl; ssl_context = ssl._create_unverified_context(); [open(path, 'wb').write(urllib.request.urlopen(url, context=ssl_context).read()) for url, path in { "https://github.com/saiadityaus1/test1/raw/main/df.csv": "df.csv", "https://github.com/saiadityaus1/test1/raw/main/df1.csv": "df1.csv", "https://github.com/saiadityaus1/test1/raw/main/dt.txt": "dt.txt", "https://github.com/saiadityaus1/test1/raw/main/file1.txt": "file1.txt", "https://github.com/saiadityaus1/test1/raw/main/file2.txt": "file2.txt", "https://github.com/saiadityaus1/test1/raw/main/file3.txt": "file3.txt", "https://github.com/saiadityaus1/test1/raw/main/file4.json": "file4.json", "https://github.com/saiadityaus1/test1/raw/main/file5.parquet": "file5.parquet", "https://github.com/saiadityaus1/test1/raw/main/file6": "file6", "https://github.com/saiadityaus1/test1/raw/main/prod.csv": "prod.csv", "https://github.com/saiadityaus1/test1/raw/main/state.txt": "state.txt", "https://github.com/saiadityaus1/test1/raw/main/usdata.csv": "usdata.csv"}.items()]

# ======================================================================================

from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
import sys

python_path = sys.executable
os.environ['PYSPARK_PYTHON'] = python_path

os.environ['JAVA_HOME'] = r''

conf = SparkConf().setAppName("pyspark").setMaster("local[*]").set("spark.driver.host","localhost").set("spark.default.parallelism", "1")
sc = SparkContext(conf=conf)

spark = SparkSession.builder.getOrCreate()

spark.read.format("csv").load("data/test.txt").toDF("Success").show(20, False)


##################🔴🔴🔴🔴🔴🔴 -> DONT TOUCH ABOVE CODE -- TYPE BELOW ####################################

print()


#############################################################################################################################



print(pdf.head())

customer_df = spark.createDataFrame(pdf)

customer_df.printSchema()

customer_df.show(5)

customer_df.write \
    .mode("overwrite") \
    .parquet(r"D:\STUDY\Capstone Proj\customer_parquet")

customer_df.write \
    .mode("overwrite") \
    .parquet(
    "s3a://curated-layer-data-capstone-proj-1/dim_customer/"
)
# Out:
# +---------------------+
# |Success              |
# +---------------------+
# |Spark Journey Started|
# +---------------------+
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_867/941376793.py in <cell line: 0>()
#      53
#      54
# ---> 55 print(pdf.head())
#      56
#      57 customer_df = spark.createDataFrame(pdf)
#
# NameError: name 'pdf' is not defined

# %%
# spark = SparkSession.builder \
#    .appName("Insurance_ETL") \
#   .config(
#   "spark.jars",
#    r"C:\Users\Shubhayu\Downloads\YOUTUBE\sqljdbc_13.4.0.0_enu\sqljdbc_13.4\enu\jars\mssql-jdbc-13.4.0.jre11.jar"
#) \
#   .getOrCreate()

import boto3
import pandas as pd

s3 = boto3.client(
    "s3",
    aws_access_key_id="AKIA2RLDGQF5PDZNVZ7Q",
    aws_secret_access_key="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",
    region_name="ap-south-1"
)

print("Connected to AWS S3")

s3.download_file(
    "raw-layer-data-capstone-proj-1",
    "Raw_Layer_Data_Storage/Notification_Raw_Data.xlsx",
    "/content/Notification_Data.xlsx"
)

pdf = pd.read_excel(
    r"/content/Notification_Data.xlsx"
)
# Out:
# Connected to AWS S3

# %%
print(pdf.head())

customer_df = spark.createDataFrame(pdf)

customer_df.printSchema()

customer_df.show(5)
# Out:
#    notification_id  cust_id notification_id.1  \
# 0                1       63           WELCOME
# 1                2      117    CLAIM_APPROVED
# 2                3      153   PAYMENT_SUCCESS
# 3                4        8    PAYMENT_FAILED
# 4                5      130   PAYMENT_SUCCESS
#
#                                   message            sent_date
# 0      Welcome to our insurance platform.  2025-08-15 15:17:00
# 1           Your claim has been approved.  2025-09-02 08:54:00
# 2  Premium payment received successfully.  2025-12-17 05:25:00
# 3   Premium payment failed. Please retry.  2025-09-29 19:49:00
# 4  Premium payment received successfully.  2025-11-10 16:30:00
# root
#  |-- notification_id: long (nullable = true)
#  |-- cust_id: long (nullable = true)
#  |-- notification_id.1: string (nullable = true)
#  |-- message: string (nullable = true)
#  |-- sent_date: string (nullable = true)
#
# +---------------+-------+-----------------+--------------------+-------------------+
# ...

# %%
import os

print(os.listdir("/content"))
# Out:
# ['.config', 'dt.txt', '\\Capstonez_Project_1\\customer_data.xlsx', 'data', 'hadoop', 'file4.json', 'usdata.csv', 'file2.txt', 'file1.txt', 'df.csv', 'customer_parquet', 'drive', 'df1.csv', '\\Capstone_Project_1\\customer_data.xlsx', 'Customer_data.xlsx', 'file6', 'file3.txt', 'prod.csv', 'file5.parquet', 'state.txt', 'sample_data']

# %%
customer_df = spark.createDataFrame(pdf)
customer_df.show()

customer_df.printSchema()
customer_df.write \
    .mode("overwrite") \
    .format("parquet")\
    .save("/content/notification_parquet")
customer_df.write \
    .mode("overwrite") \
    .format("csv")\
    .option("header", "true")\
    .save("/content/notification_csv")

customer_df.write \
    .mode("overwrite") \
    .format("json")\
    .save("/content/notification_json")
# Out:
# +---------------+-------+-----------------+--------------------+-------------------+
# |notification_id|cust_id|notification_id.1|             message|          sent_date|
# +---------------+-------+-----------------+--------------------+-------------------+
# |              1|     63|          WELCOME|Welcome to our in...|2025-08-15 15:17:00|
# |              2|    117|   CLAIM_APPROVED|Your claim has be...|2025-09-02 08:54:00|
# |              3|    153|  PAYMENT_SUCCESS|Premium payment r...|2025-12-17 05:25:00|
# |              4|      8|   PAYMENT_FAILED|Premium payment f...|2025-09-29 19:49:00|
# |              5|    130|  PAYMENT_SUCCESS|Premium payment r...|2025-11-10 16:30:00|
# |              6|    123|   POLICY_RENEWED|Your policy has b...|2025-07-01 14:53:00|
# |              7|    128|   CLAIM_APPROVED|Your claim has be...|2025-07-18 13:15:00|
# |              8|    105|      PREMIUM_DUE|Your premium paym...|2025-06-22 10:41:00|
# ...

# %%
import os

# Rename file
os.rename(
    "/content/notification_csv/part-00000-feb537fb-5218-42bb-ab51-c80325fa15e0-c000.csv",
    "/content/notification_csv/Notification_Data.csv"
)

os.rename(
    "/content/notification_json/part-00000-d66497d9-b071-45cd-9fa4-4c1a4781e614-c000.json",
    "/content/notification_csv/Notification_Data.json"
)

os.rename(
    "/content/notification_parquet/part-00000-70f51309-14d0-49ee-93f1-29cb5d2c81c5-c000.snappy.parquet",
    "/content/notification_csv/Notification_Data.parquet"
)

print("File renamed successfully.")
# Out:
# File renamed successfully.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

print(spark.version)
# Out:
# 4.0.3

# %% [markdown]
# # *INSTALL LIBRARIES*

# %%
# !pip install boto3 openpyxl pandas pyarrow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 49.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 kB 3.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # *CONNECT TO AWS S3 , Download the Files and Save in Drive , then Converting the File into DATAFRAME , then Converting and Saving the Dataframes into Different File Formats - .csv , .json , .parquet , .avro , .orc*

# %%
# spark = SparkSession.builder \
#    .appName("Insurance_ETL") \
#   .config(
#   "spark.jars",
#    r"C:\Users\Shubhayu\Downloads\YOUTUBE\sqljdbc_13.4.0.0_enu\sqljdbc_13.4\enu\jars\mssql-jdbc-13.4.0.jre11.jar"
#) \
#   .getOrCreate()


############################## CONNECT TO AWS S3 via Acess Key ans Secret Access Key ##################

import boto3
import pandas as pd

s3 = boto3.client(
    "s3",
    aws_access_key_id="AKIA2RLDGQF5PDZNVZ7Q",
    aws_secret_access_key="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",
    region_name="ap-south-1"
)

print("Connected to AWS S3")

##################################### DOWNLOAD THE FILE & SAVE IN GOOGLE DRIVE ###############

s3.download_file(
    "raw-layer-data-capstone-proj-1",
    "Raw_Layer_Data_Storage/.xlsx-Files/Users_Raw_Data.xlsx",
    "/content/Users_Data.xlsx"
)

pdf = pd.read_excel(
    r"/content/Users_Data.xlsx"
)

############################# CONVERT THE EXCEL FILE INTO DATAFRAME ################################


print(pdf.head())

customer_df = spark.createDataFrame(pdf)

customer_df.printSchema()

customer_df.show(5)


########################### CONVERT & SAVE THE FILES IN DIFERENT FORMATS ##################################

customer_df = spark.createDataFrame(pdf)
customer_df.show()

customer_df.printSchema()
customer_df.write \
    .mode("overwrite") \
    .format("parquet")\
    .save("/content/Users_parquet")
customer_df.write \
    .mode("overwrite") \
    .format("csv")\
    .option("header", "true")\
    .save("/content/Users_csv")

customer_df.write \
    .mode("overwrite") \
    .format("json")\
    .save("/content/Users_json")

'''
customer_df.write \
    .mode("overwrite") \
    .format("avro")\
    .save("/content/Users_avro")

'''

customer_df.write \
    .mode("overwrite") \
    .format("orc")\
    .save("/content/Users_orc")
# Out:
# Connected to AWS S3
#    user_id          user_name password_hash            role
# 0        1           admin001   HASH_000001           ADMIN
# 1        2  branch_manager002   HASH_000002  BRANCH_MANAGER
# 2        3        employee003   HASH_000003        EMPLOYEE
# 3        4           agent004   HASH_000004           AGENT
# 4        5        customer005   HASH_000005        CUSTOMER
# root
#  |-- user_id: long (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- password_hash: string (nullable = true)
#  |-- role: string (nullable = true)
#
# +-------+-----------------+-------------+--------------+
# |user_id|        user_name|password_hash|          role|
# +-------+-----------------+-------------+--------------+
# |      1|         admin001|  HASH_000001|         ADMIN|
# |      2|branch_manager002|  HASH_000002|BRANCH_MANAGER|
# |      3|      employee003|  HASH_000003|      EMPLOYEE|
# |      4|         agent004|  HASH_000004|         AGENT|
# ...

# %% [markdown]
# #  *RENAMING The FILES*

# %%
################################ RENAME FILES #####################################

import os
# Rename file

os.rename(
    "/content/Users_csv/part-00000-f7ff2500-eb7a-46d9-b28f-3b736eaa1035-c000.csv",
    "/content/Users_csv/Users_Data.csv"
)

os.rename(
    "/content/Users_json/part-00000-09dc6157-2693-4c3f-8dc3-9ef897b616de-c000.json",
    "/content/Users_json/Users_Data.json"
)

os.rename(
    "/content/Users_orc/part-00000-3e8d7f30-12e1-4c14-9471-1135991fbb27-c000.zstd.orc",
    "/content/Users_orc/Users_Data.orc"
)

os.rename(
    "/content/Users_parquet/part-00000-ad044fcf-4f88-46fb-9dbf-8ad4b5335c4a-c000.snappy.parquet",
    "/content/Users_parquet/Users_Data.parquet"
)


print("File renamed successfully.")
# Out:
# File renamed successfully.

# %%
spark.stop()

from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Insurance_ETL") \
    .config(
        "spark.jars.packages",
        "org.apache.spark:spark-avro_2.13:4.0.0"
    ) \
    .getOrCreate()
